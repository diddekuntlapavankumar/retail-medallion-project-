# %%
dbutils.notebook.run("01_Bronze_Ingestion", 300)
dbutils.notebook.run("02_Silver_Transformation", 300)
dbutils.notebook.run("03_Gold_Aggregation", 300)

print("Pipeline completed successfully")
